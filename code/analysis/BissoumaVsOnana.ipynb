# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from soccerplots.radar_chart import Radar

# %%
url = 'https://fbref.com/en/comps/Big5/passing/players/Big-5-European-Leagues-Stats'

# %%
df = pd.read_html(url)[0]
#add [0] because we just want the first item in the df list

# %%
df
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                      Rk             Player             Nation
# 0                     1         Max Aarons            eng ENG
# 1                     2   Brenden Aaronson             us USA
# 2                     3    Paxten Aaronson             us USA
# 3                     4  Keyliane Abdallah             fr FRA
# 4                     5   Yunis Abdelhamid             ma MAR
# ...                 ...                ...                ...
# 2882               2773    Martin Ødegaard             no NOR
# 2883               2774        Milan Đurić             ba BIH
# 2884               2775        Milan Đurić             ba BIH
# 2885                 Rk             Player             Nation
# 2886               2776   Mateusz Łęgowski             pl POL
#
#      Unnamed: 3_level_0 Unnamed: 4_level_0  Unnamed: 5_level_0  \
#                     Pos              Squad                Comp
# ...

# %%
df.columns
# Out:
# MultiIndex([( 'Unnamed: 0_level_0',      'Rk'),
#             ( 'Unnamed: 1_level_0',  'Player'),
#             ( 'Unnamed: 2_level_0',  'Nation'),
#             ( 'Unnamed: 3_level_0',     'Pos'),
#             ( 'Unnamed: 4_level_0',   'Squad'),
#             ( 'Unnamed: 5_level_0',    'Comp'),
#             ( 'Unnamed: 6_level_0',     'Age'),
#             ( 'Unnamed: 7_level_0',    'Born'),
#             ( 'Unnamed: 8_level_0',     '90s'),
#             (              'Total',     'Cmp'),
#             (              'Total',     'Att'),
#             (              'Total',    'Cmp%'),
#             (              'Total', 'TotDist'),
#             (              'Total', 'PrgDist'),
#             (              'Short',     'Cmp'),
#             (              'Short',     'Att'),
#             (              'Short',    'Cmp%'),
#             (             'Medium',     'Cmp'),
#             (             'Medium',     'Att'),
#             (             'Medium',    'Cmp%'),
# ...

# %%
df.columns = ['_'.join(col).strip() for col in df.columns.values]

# %%
df.columns
# Out:
# Index(['Unnamed: 0_level_0_Rk', 'Unnamed: 1_level_0_Player',
#        'Unnamed: 2_level_0_Nation', 'Unnamed: 3_level_0_Pos',
#        'Unnamed: 4_level_0_Squad', 'Unnamed: 5_level_0_Comp',
#        'Unnamed: 6_level_0_Age', 'Unnamed: 7_level_0_Born',
#        'Unnamed: 8_level_0_90s', 'Total_Cmp', 'Total_Att', 'Total_Cmp%',
#        'Total_TotDist', 'Total_PrgDist', 'Short_Cmp', 'Short_Att',
#        'Short_Cmp%', 'Medium_Cmp', 'Medium_Att', 'Medium_Cmp%', 'Long_Cmp',
#        'Long_Att', 'Long_Cmp%', 'Unnamed: 23_level_0_Ast',
#        'Unnamed: 24_level_0_xAG', 'Expected_xA', 'Expected_A-xAG',
#        'Unnamed: 27_level_0_KP', 'Unnamed: 28_level_0_1/3',
#        'Unnamed: 29_level_0_PPA', 'Unnamed: 30_level_0_CrsPA',
#        'Unnamed: 31_level_0_PrgP', 'Unnamed: 32_level_0_Matches'],
#       dtype='object')

# %%
df.columns.values
# Out:
# array(['Unnamed: 0_level_0_Rk', 'Unnamed: 1_level_0_Player',
#        'Unnamed: 2_level_0_Nation', 'Unnamed: 3_level_0_Pos',
#        'Unnamed: 4_level_0_Squad', 'Unnamed: 5_level_0_Comp',
#        'Unnamed: 6_level_0_Age', 'Unnamed: 7_level_0_Born',
#        'Unnamed: 8_level_0_90s', 'Total_Cmp', 'Total_Att', 'Total_Cmp%',
#        'Total_TotDist', 'Total_PrgDist', 'Short_Cmp', 'Short_Att',
#        'Short_Cmp%', 'Medium_Cmp', 'Medium_Att', 'Medium_Cmp%',
#        'Long_Cmp', 'Long_Att', 'Long_Cmp%', 'Unnamed: 23_level_0_Ast',
#        'Unnamed: 24_level_0_xAG', 'Expected_xA', 'Expected_A-xAG',
#        'Unnamed: 27_level_0_KP', 'Unnamed: 28_level_0_1/3',
#        'Unnamed: 29_level_0_PPA', 'Unnamed: 30_level_0_CrsPA',
#        'Unnamed: 31_level_0_PrgP', 'Unnamed: 32_level_0_Matches'],
#       dtype=object)

# %%
df.head()
# Out:
#   Unnamed: 0_level_0_Rk Unnamed: 1_level_0_Player Unnamed: 2_level_0_Nation  \
# 0                     1                Max Aarons                   eng ENG
# 1                     2          Brenden Aaronson                    us USA
# 2                     3           Paxten Aaronson                    us USA
# 3                     4         Keyliane Abdallah                    fr FRA
# 4                     5          Yunis Abdelhamid                    ma MAR
#
#   Unnamed: 3_level_0_Pos Unnamed: 4_level_0_Squad Unnamed: 5_level_0_Comp  \
# 0                     DF              Bournemouth      eng Premier League
# 1                  MF,FW             Union Berlin           de Bundesliga
# 2                     MF           Eint Frankfurt           de Bundesliga
# 3                     FW                Marseille              fr Ligue 1
# 4                     DF                    Reims              fr Ligue 1
#
# ...

# %%
df = df[(df['Unnamed: 1_level_0_Player'] == "Yves Bissouma") | (df['Unnamed: 1_level_0_Player'] == "Amadou Onana")]

# %%
df.head()
# Out:
#      Unnamed: 0_level_0_Rk Unnamed: 1_level_0_Player  \
# 319                    308             Yves Bissouma
# 1996                  1921              Amadou Onana
#
#      Unnamed: 2_level_0_Nation Unnamed: 3_level_0_Pos  \
# 319                     ml MLI                     MF
# 1996                    be BEL                     MF
#
#      Unnamed: 4_level_0_Squad Unnamed: 5_level_0_Comp Unnamed: 6_level_0_Age  \
# 319                 Tottenham      eng Premier League                 27-244
# 1996                  Everton      eng Premier League                 22-258
#
#      Unnamed: 7_level_0_Born Unnamed: 8_level_0_90s Total_Cmp  ...  \
# 319                     1996                   20.5      1525  ...
# 1996                    2001                   20.8       785  ...
#
#      Unnamed: 23_level_0_Ast Unnamed: 24_level_0_xAG Expected_xA  \
# 319                        0                     0.4         1.6
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#    index Unnamed: 0_level_0_Rk Unnamed: 1_level_0_Player  \
# 0    319                   308             Yves Bissouma
# 1   1996                  1921              Amadou Onana
#
#   Unnamed: 2_level_0_Nation Unnamed: 3_level_0_Pos Unnamed: 4_level_0_Squad  \
# 0                    ml MLI                     MF                Tottenham
# 1                    be BEL                     MF                  Everton
#
#   Unnamed: 5_level_0_Comp Unnamed: 6_level_0_Age Unnamed: 7_level_0_Born  \
# 0      eng Premier League                 27-244                    1996
# 1      eng Premier League                 22-258                    2001
#
#   Unnamed: 8_level_0_90s  ... Unnamed: 23_level_0_Ast Unnamed: 24_level_0_xAG  \
# 0                   20.5  ...                       0                     0.4
# 1                   20.8  ...                       0                     2.7
#
#   Expected_xA Expected_A-xAG Unnamed: 27_level_0_KP Unnamed: 28_level_0_1/3  \
# ...

# %%
df = df.drop(['Unnamed: 0_level_0_Rk', 'Unnamed: 2_level_0_Nation', 'Unnamed: 3_level_0_Pos', 'Unnamed: 4_level_0_Squad', 'Unnamed: 5_level_0_Comp',
             'Unnamed: 6_level_0_Age', 'Unnamed: 7_level_0_Born', 'Unnamed: 32_level_0_Matches'], axis=1)

# %%
df = df.drop(['index'], axis=1)

# %%
df.values
# Out:
# array([['Yves Bissouma', '20.5', '1525', '1655', '92.1', '22517', '6324',
#         '856', '905', '94.6', '553', '593', '93.3', '56', '69', '81.2',
#         '0', '0.4', '1.6', '-0.4', '9', '137', '10', '0', '146'],
#        ['Amadou Onana', '20.8', '785', '935', '84.0', '13104', '3702',
#         '406', '455', '89.2', '277', '320', '86.6', '78', '106', '73.6',
#         '0', '2.7', '1.3', '-2.7', '18', '94', '13', '1', '101']],
#       dtype=object)

# %%
df.values[1]
# Out:
# array(['Amadou Onana', '20.8', '785', '935', '84.0', '13104', '3702',
#        '406', '455', '89.2', '277', '320', '86.6', '78', '106', '73.6',
#        '0', '2.7', '1.3', '-2.7', '18', '94', '13', '1', '101'],
#       dtype=object)

# %%
df.values[0]
# Out:
# array(['Yves Bissouma', '20.5', '1525', '1655', '92.1', '22517', '6324',
#        '856', '905', '94.6', '553', '593', '93.3', '56', '69', '81.2',
#        '0', '0.4', '1.6', '-0.4', '9', '137', '10', '0', '146'],
#       dtype=object)

# %%
df
# Out:
#   Unnamed: 1_level_0_Player Unnamed: 8_level_0_90s Total_Cmp Total_Att  \
# 0             Yves Bissouma                   20.5      1525      1655
# 1              Amadou Onana                   20.8       785       935
#
#   Total_Cmp% Total_TotDist Total_PrgDist Short_Cmp Short_Att Short_Cmp%  ...  \
# 0       92.1         22517          6324       856       905       94.6  ...
# 1       84.0         13104          3702       406       455       89.2  ...
#
#   Long_Cmp% Unnamed: 23_level_0_Ast Unnamed: 24_level_0_xAG Expected_xA  \
# 0      81.2                       0                     0.4         1.6
# 1      73.6                       0                     2.7         1.3
#
#   Expected_A-xAG Unnamed: 27_level_0_KP Unnamed: 28_level_0_1/3  \
# 0           -0.4                      9                     137
# 1           -2.7                     18                      94
#
#   Unnamed: 29_level_0_PPA Unnamed: 30_level_0_CrsPA Unnamed: 31_level_0_PrgP
# ...

# %%
#df = df[:,2:].astype(float)
player1 = []
player2 = []

print(len(df.values))

#for x in range(len(df.values)):

for i in df.values[0]:
    if any(chr.isdigit() for chr in i):
        y = float(i)
    else:
        y = i
        
    player1.append(y)


player1 = np.array(player1)
print(player1)
df.values[0] = player1
print(df.values[0])
# Out:
# 2
# ['Yves Bissouma' '20.5' '1525.0' '1655.0' '92.1' '22517.0' '6324.0'
#  '856.0' '905.0' '94.6' '553.0' '593.0' '93.3' '56.0' '69.0' '81.2' '0.0'
#  '0.4' '1.6' '-0.4' '9.0' '137.0' '10.0' '0.0' '146.0']
# ['Yves Bissouma' '20.5' '1525.0' '1655.0' '92.1' '22517.0' '6324.0'
#  '856.0' '905.0' '94.6' '553.0' '593.0' '93.3' '56.0' '69.0' '81.2' '0.0'
#  '0.4' '1.6' '-0.4' '9.0' '137.0' '10.0' '0.0' '146.0']

# %%
for i in df.values[1]:
    if any(chr.isdigit() for chr in i):
        y = float(i)
    else:
        y = i
        
    player2.append(y)

player2 = np.array(player2)
print(player2)

newArr = np.vstack((player1, player2))
newArr

# %%
#get parameters
params = list(df.columns)
params = params[2:]
params
# Out:
# ['Unnamed: 8_level_0_90s',
#  'Total_Cmp',
#  'Total_Att',
#  'Total_Cmp%',
#  'Total_TotDist',
#  'Total_PrgDist',
#  'Short_Cmp',
#  'Short_Att',
#  'Short_Cmp%',
#  'Medium_Cmp',
#  'Medium_Att',
#  'Medium_Cmp%',
#  'Long_Cmp',
#  'Long_Att',
#  'Long_Cmp%',
#  'Unnamed: 23_level_0_Ast',
#  'Unnamed: 24_level_0_xAG',
#  'Expected_xA',
#  'Expected_A-xAG',
#  'Unnamed: 27_level_0_KP',
#  'Unnamed: 28_level_0_1/3',
#  'Unnamed: 29_level_0_PPA',
#  'Unnamed: 30_level_0_CrsPA',
#  'Unnamed: 31_level_0_PrgP']

# %%
print(df.dtypes)
# Out:
# index                         int64
# Unnamed: 1_level_0_Player    object
# Unnamed: 8_level_0_90s       object
# Total_Cmp                    object
# Total_Att                    object
# Total_Cmp%                   object
# Total_TotDist                object
# Total_PrgDist                object
# Short_Cmp                    object
# Short_Att                    object
# Short_Cmp%                   object
# Medium_Cmp                   object
# Medium_Att                   object
# Medium_Cmp%                  object
# Long_Cmp                     object
# Long_Att                     object
# Long_Cmp%                    object
# Unnamed: 23_level_0_Ast      object
# Unnamed: 24_level_0_xAG      object
# Expected_xA                  object
# Expected_A-xAG               object
# Unnamed: 27_level_0_KP       object
# Unnamed: 28_level_0_1/3      object
# Unnamed: 29_level_0_PPA      object
# Unnamed: 30_level_0_CrsPA    object
# Unnamed: 31_level_0_PrgP     object
# ...

# %%
#ranges
#add ranges to list of tuple pairs
#create empty lists

ranges = []
a_values = []
b_values = []

for x in params:
    print(x)
    a = min(df[params][x])
    print(a)
    print(type(a))
    a = a - (a*0.25)

    b = max(df[params][x])
    b = b + (b*0.25)

    ranges.append((a,b))

#values
for x in range(len(df['Unnamed: 1_level_0_Player'])):
    if df['Unnamed: 1_level_0_Player'][x] == 'Yves Bissouma':
        a_values = df.iloc[x].values.tolist()
    if df['Unnamed: 1_level_0_Player'][x] == 'Amadou Onana':
        b_values = df.iloc[x].values.tolist()

a_values = a_values[2:]
b_values = b_values[2:]
values = [a_values, b_values]
values
# Out:
# Unnamed: 8_level_0_90s
# 20.5
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 14
#      12 print(a)
#      13 print(type(a))
# ---> 14 a = a - (a*0.25)
#      16 b = max(df[params][x])
#      17 b = b + (b*0.25)
#
# TypeError: can't multiply sequence by non-int of type 'float'
