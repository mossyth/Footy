# %%
import pandas as pd
import numpy as np
import seaborn as sns
from PIL import Image

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from soccerplots.radar_chart import Radar

# %%
GKdf = pd.read_csv('C:/Users/tomas.hehir/Source/Repos/Footy/data/Arsenal/ArsenalKeepers.csv')
DEFdf = pd.read_csv('C:/Users/tomas.hehir/Source/Repos/Footy/data/Arsenal/ArsenalDefenders.csv')
MIDdf = pd.read_csv('C:/Users/tomas.hehir/Source/Repos/Footy/data/Arsenal/ArsenalMidfielders.csv')
ATTdf = pd.read_csv('C:/Users/tomas.hehir/Source/Repos/Footy/data/Arsenal/ArsenalAttackers.csv')

# %%
all_players_df = [GKdf, DEFdf, MIDdf, ATTdf]

# %%
ATTdf = ATTdf.drop('Unnamed: 0', axis=1)
MIDdf = MIDdf.drop('Unnamed: 0', axis=1)
DEFdf = DEFdf.drop('Unnamed: 0', axis=1)
GKdf = GKdf.drop('Unnamed: 0', axis=1)

# %%
def plotComp(df, playerA, seasonA, playerB, seasonB):
    params = list(df.columns)
    params = params[2:-1]

    ranges = []
    a_values = []
    b_values = []

    for x in params:
        a = min(df[params][x])
        a -= (a*.15)

        b = max(df[params][x])
        b += (b*.15)

        ranges.append((a,b))

    for x in range(len(df['Player'])):
        if (df['Player'][x] == playerA) & (df['Season'][x] == seasonA):
            a_values = df.iloc[x].values.tolist()
        if (df['Player'][x] == playerB) & (df['Season'][x] == seasonB):
            b_values = df.iloc[x].values.tolist()

    a_values = a_values[2:-1]
    b_values = b_values[2:-1]
    values = [a_values, b_values]

    title = dict(
    title_name = playerA,
    title_color = 'white',
    subtitle_name='2022/23',
    subtitle_color='white',
    title_name_2 = playerB,
    title_color_2 = 'red',
    subtitle_name_2='2023/24',
    subtitle_color_2='red',
    title_fontsize = 18)
    endnote = '\n mossystats'

    filename=f"{playerA.split()[-1]}{seasonA}vs{playerB.split()[-1]}{seasonB}.jpg"
    
    radar = Radar(background_color="black", patch_color="#28252C", label_color="#F0FFF0",
                range_color="#F0FFF0")

    fig, ax = radar.plot_radar(ranges=ranges, params=params, values=values, 
                            radar_color = ['white','red'], alphas=[0.8, 0.6], title=title, 
                            endnote=endnote, end_color='green', dpi=700, alpha= 0.7,
                            image='C:/Users/tomas.hehir/Source/Repos/Footy/images/arsenalcrest.jpg', image_coord=[0.495, 0.805, 0.04, 0.1], 
                            filename=f"C:/Users/tomas.hehir/Source/Repos/Footy/outputs/arsenal/{filename}",
                            compare=True)

# %%
plotComp(GKdf, "Aaron Ramsdale", 2023, "David Raya", 2024)

plotComp(DEFdf, "Ben White", 2023, "Ben White", 2024)
plotComp(DEFdf, "William Saliba", 2023, "William Saliba", 2024)
plotComp(DEFdf, "Gabriel Magalhães", 2023, "Gabriel Magalhães", 2024)
plotComp(DEFdf, "Oleksandr Zinchenko", 2023, "Oleksandr Zinchenko", 2024)

plotComp(MIDdf, "Thomas Partey", 2023, "Jorginho", 2024)
plotComp(MIDdf, "Granit Xhaka", 2023, "Declan Rice", 2024)
plotComp(MIDdf, "Martin Ødegaard", 2023, "Martin Ødegaard", 2024)

plotComp(ATTdf, "Bukayo Saka", 2023, "Bukayo Saka", 2024)
plotComp(ATTdf, "Gabriel Jesus", 2023, "Kai Havertz", 2024)
plotComp(ATTdf, "Gabriel Martinelli", 2023, "Leandro Trossard", 2024)

# %%
fig = plt.figure(figsize=(25,18))

fig.patch.set_facecolor('black')

#ax = fig.add_axes([left, bottom, width, height])

ax1 = fig.add_axes([0.5, 0.9, 0.3, 0.3])
team1_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/outputs/arsenal/Ramsdale2023vsRaya2024.jpg')
ax1.imshow(team1_img)
ax1.axis('off')

ax2 = fig.add_axes([0.1, 0.7, 0.3, 0.3])
team2_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/outputs/arsenal/White2023vsWhite2024.jpg')
ax2.imshow(team2_img)
ax2.axis('off')

ax3 = fig.add_axes([0.9, 0.7, 0.3, 0.3])
team3_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/outputs/arsenal/Zinchenko2023vsZinchenko2024.jpg')
ax3.imshow(team3_img)
ax3.axis('off')

ax4 = fig.add_axes([0.3, 0.7, 0.3, 0.3])
team4_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/outputs/arsenal/Saliba2023vsSaliba2024.jpg')
ax4.imshow(team4_img)
ax4.axis('off')

ax5 = fig.add_axes([0.7, 0.7, 0.3, 0.3])
team5_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/outputs/arsenal/Magalhães2023vsMagalhães2024.jpg')
ax5.imshow(team5_img)
ax5.axis('off')

ax6 = fig.add_axes([0.5, 0.5, 0.3, 0.3])
team6_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/outputs/arsenal/Partey2023vsJorginho2024.jpg')
ax6.imshow(team6_img)
ax6.axis('off')

ax7 = fig.add_axes([0.1, 0.15, 0.3, 0.3])
radar7_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/outputs/arsenal/Saka2023vsSaka2024.jpg')
ax7.imshow(radar7_img)
ax7.axis('off')

ax8 = fig.add_axes([0.7, 0.35, 0.3, 0.3])
radar8_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/outputs/arsenal/Xhaka2023vsRice2024.jpg')
ax8.imshow(radar8_img)
ax8.axis('off')

ax9 = fig.add_axes([0.5, 0.05, 0.3, 0.3])
radar9_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/outputs/arsenal/Jesus2023vsHavertz2024.jpg')
ax9.imshow(radar9_img)
ax9.axis('off')

ax10 = fig.add_axes([0.3, 0.35, 0.3, 0.3])
radar10_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/outputs/arsenal/Ødegaard2023vsØdegaard2024.jpg')
ax10.imshow(radar10_img)
ax10.axis('off')

ax11 = fig.add_axes([0.9, 0.15, 0.3, 0.3])
radar11_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/outputs/arsenal/Martinelli2023vsTrossard2024.jpg')
ax11.imshow(radar11_img)
ax11.axis('off')

ax12 = fig.add_axes([0.22, 0.98, 0.1, 0.1])
badge_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/images/arsenalcrest.jpg')
ax12.imshow(badge_img)

ax13 = fig.add_axes([0.2, 0.999, 0.1, 0.1])
ax13.text(0.2, 0.97, '22/23 vs 23/24', fontsize=20, color='white', fontdict={'family': 'monospace'})
ax13.axis('off')

ax14 = fig.add_axes([0.92, 0.01, 0.06, 0.06])
X_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/images/X.png')
ax14.imshow(X_img)

ax15 = fig.add_axes([0.76, 0.03, 0.07, 0.07])
ax15.text(0.76, 0.03, 'Created by @mossy_1998', fontsize=16, color='white', fontdict={'family': 'monospace'})
ax15.axis('off')

ax16 = fig.add_axes([0.43, 0.01, 0.05, 0.05])
FBREF_img = Image.open('C:/Users/tomas.hehir/Source/Repos/Footy/images/FBREF.png')
ax16.imshow(FBREF_img)

ax17 = fig.add_axes([0.35, 0.03, 0.07, 0.07])
ax17.text(0.35, 0.03, 'Data from', fontsize=16, color='white', fontdict={'family': 'monospace'})
ax17.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
fig.savefig('C:/Users/tomas.hehir/Source/Repos/Footy/outputs/arsenal/ArsenalDashboard.png', dpi=620, bbox_inches='tight')
